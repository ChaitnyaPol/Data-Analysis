# %%
import pandas as pd
import numpy as np

# %%
# # import the necessary libraries
# import seaborn as sns
# import matplotlib.pyplot as plt
 
# # to ignore the warnings
# from warnings import filterwarnings
 
# # load the dataset
# df = sns.load_dataset('tips')
 
# # the first five entries of the dataset
# df.head()

# %%
# # set the background style of the plot
# sns.set_style('whitegrid')
# sns.distplot(df['total_bill'], kde = False, color ='red', bins = 30)

# %%
# sns.jointplot(x ='total_bill', y ='tip', data = df)

# %%
# sns.jointplot(x ='total_bill', y ='tip', data = df, kind ='kde')
# sns.jointplot(x ='total_bill', y ='tip', data = df)
# # KDE shows the density where the points match up the most

# %%
# sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
# x = np.random.randn(100)
# ax = sns.distplot(x)
# plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns, numpy as np
# from pylab import *

# sns.set(rc={"figure.figsize": (8, 4)}); np.random.seed(0)
# x = np.random.randn(100)

# subplot(2,2,1)
# ax = sns.distplot(x)

# subplot(2,2,2)
# ax = sns.distplot(x, rug=False, hist=False)

# subplot(2,2,3)
# ax = sns.distplot(x, vertical=True)

# subplot(2,2,4)
# ax = sns.kdeplot(x, shade=True, color="r")

# plt.show()

# %%
data=pd.read_csv(r"C:\Users\comp\Downloads\heart.csv")
data
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
from sklearn.preprocessing import LabelEncoder
L1=LabelEncoder()
data["Sex"]=L1.fit_transform(data["Sex"])
data["ChestPainType"]=L1.fit_transform(data["ChestPainType"])
data["RestingECG"]=L1.fit_transform(data["RestingECG"])
data["ExerciseAngina"]=L1.fit_transform(data["ExerciseAngina"])
data["ST_Slope"]=L1.fit_transform(data["ST_Slope"])
data
# Out:
#      Age  Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  RestingECG  \
# 0     40    1              1        140          289          0           1
# 1     49    0              2        160          180          0           1
# 2     37    1              1        130          283          0           2
# 3     48    0              0        138          214          0           1
# 4     54    1              2        150          195          0           1
# ..   ...  ...            ...        ...          ...        ...         ...
# 913   45    1              3        110          264          0           1
# 914   68    1              0        144          193          1           1
# 915   57    1              0        130          131          0           1
# 916   57    0              1        130          236          0           0
# 917   38    1              2        138          175          0           1
#
# ...

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# fig,axes=plt.subplots(1,2)
# sns.distplot(data,ax=axes[0])
# plt.grid(True)
# sns.distplot(data,rug=True,ax=axes[1])
# plt.show()

# %%
# for x in data.columns:
#     ax = sns.distplot(x)
#     plt.show()

# %%
x1=data.iloc[:,:-1].values
y1=data.iloc[:,-1].values

# %%
from imblearn.over_sampling import SMOTE
s11=SMOTE()
x_data1,y_data1=s11.fit_resample(x1,y1)

# %%
from sklearn.model_selection import train_test_split
x_train1,x_test1,y_train1,y_test1=train_test_split(x_data1,y_data1,test_size=0.2,random_state=11)

# %%
from sklearn.linear_model import LogisticRegression
l1=LogisticRegression()
l1.fit(x_train1,y_train1)
# Out:
# C:\Users\comp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_train_bal=l1.predict(x_train1)

from sklearn.metrics import accuracy_score
ac2=accuracy_score(y_train_bal,y_train1)*100
ac2
# Out:
# 86.57635467980296

# %%
y_test_bal=l1.predict(x_test1)

from sklearn.metrics import accuracy_score
ac3=accuracy_score(y_test_bal,y_test1)*100
ac3
# Out:
# 79.41176470588235

# %%
var_train=y_data1.var()

sse=np.mean(np.mean(y_train_bal-y_train1)**2)
bias1=sse-var_train
bias1
# Out:
# -0.24998635006915965

# %%
var_test=y_data1.var()

sse=np.mean(np.mean(y_test_bal-y_test)**2)
bias11=sse-var_test
bias11

# %%
creditcard

# %%
data=pd.read_csv(r"C:\Users\comp\Downloads\creditcard.csv")
data
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...
